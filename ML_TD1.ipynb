# %% [markdown]
# <a href="https://colab.research.google.com/github/ESKINDERTSEGAYE/Programming/blob/main/ML_TD1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

n_samples = 100

x = np.random.rand(n_samples)
y = np.random.rand(1)* x + np.random.rand(n_samples)
plt.scatter(x,y)
