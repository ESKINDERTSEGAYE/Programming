# %% [markdown]
# <a href="https://colab.research.google.com/github/ESKINDERTSEGAYE/Programming/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# packages

# standard
import statistics
import numpy as np
import pandas as pd
import time

# plot
import matplotlib.pyplot as plt
import seaborn as sns

# statistics tools
from statsmodels.graphics.mosaicplot import mosaic

from h2o.estimators import H2OGradientBoostingEstimator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-31867cabfbc2> in <module>()
#      15
#      16 # ML
# ---> 17 import h2o
#      18 from h2o.estimators import H2ORandomForestEstimator
#      19 from h2o.estimators import H2OGradientBoostingEstimator
#
# ModuleNotFoundError: No module named 'h2o'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# load data
df = pd.read_csv("healthcare-dataset-stroke-data.csv")
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# dimensions of data
df.shape
# Out:
# (5110, 12)

# %%
# data cleansing
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
We have missing values for BMI!

# %%
# Calculating the mean of column bmi
df_mean = df["bmi"].mean()
print(df_mean)
# Out:
# 28.893236911794673

# %%
# Replace the missing value with the mean
df.bmi = df.bmi.fillna(df_mean)

# %%
# rename columns
df.rename(columns = {'Residence_type':'residence_type'}, inplace = True)

# %%
# define target variable
df['target'] = df.stroke
df = df.drop(['stroke'], axis=1) # remove stroke column

# %% [markdown]
# Numerical Features

# %%
# select numerical features
features_num = ['age', 'avg_glucose_level','bmi']

# %%
# basic stats
df[features_num].describe(percentiles=[0.1,0.25,0.5,0.75,0.9])
# Out:
#                age  avg_glucose_level          bmi
# count  5110.000000        5110.000000  5110.000000
# mean     43.226614         106.147677    28.893237
# std      22.612647          45.283560     7.698018
# min       0.080000          55.120000    10.300000
# 10%      11.000000          65.789000    19.890000
# 25%      25.000000          77.245000    23.800000
# 50%      45.000000          91.885000    28.400000
# 75%      61.000000         114.090000    32.800000
# 90%      75.000000         192.181000    38.700000
# max      82.000000         271.740000    97.600000

# %%
# plot distribution of numerical features
for f in features_num:
    df[f].plot(kind='hist', bins=50)
    plt.title(f)
    plt.grid()
    plt.show()

# %%
# pairwise scatter plot
sns.pairplot(df[features_num], 
             kind='reg', 
             plot_kws={'line_kws':{'color':'magenta'}, 'scatter_kws': {'alpha': 0.1}})
plt.show()

# %%
# Spearman (Rank) correlation
corr_spearman = df[features_num].corr(method='spearman')

fig = plt.figure(figsize = (6,5))
sns.heatmap(corr_spearman, annot=True, cmap="RdYlGn", vmin=-1, vmax=+1)
plt.title('Spearman Correlation')
plt.show()

# %% [markdown]
# Categorical Features

# %%
features_cat = ['gender','hypertension','heart_disease','ever_married',
               'work_type','residence_type','smoking_status']

# %%
for f in features_cat:
    df[f].value_counts().plot(kind='bar')
    plt.title(f)
    plt.grid()
    plt.show()

# %% [markdown]
# Target

# %%
# calc frequencies
target_count = df.target.value_counts()
print(target_count)
print()
print('Percentage of strokes [1]:', np.round(100*target_count[1] / target_count.sum(),2), '%')
# Out:
# 0    4861
# 1     249
# Name: target, dtype: int64
#
# Percentage of strokes [1]: 4.87 %

# %%
# plot target distribution
target_count.plot(kind='bar')
plt.title('Target = Stroke')
plt.grid()
plt.show()

# %% [markdown]
# Target vs Numerical Features

# %%
# add binned version of numerical features

# quantile based:
df['age_bin'] = pd.qcut(df['age'], q=10, precision=1)
df['avg_glucose_level_bin'] = pd.qcut(df['avg_glucose_level'], q=10, precision=1)

# explicitly defined bins:
df['bmi_bin'] = pd.cut(df['bmi'], [-100,10,20,25,30,35,40,50,100])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-658b1c5f225b> in <module>()
#       2
#       3 # quantile based:
# ----> 4 df['age_bin'] = pd.qcut(df['age'], q=10, precision=1)
#       5 df['avg_glucose_level_bin'] = pd.qcut(df['avg_glucose_level'], q=10, precision=1)
#       6
#
# NameError: name 'df' is not defined
